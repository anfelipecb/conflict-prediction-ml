# %% [markdown]
# # Conclusion: What did you learn about your research question? What did you learn about machine learning through the tasks?  How would you continue this research if you wanted to further investigate? If you had more time and infinite resources, how would you continue your project?

# %% [markdown]
# - Aprendizajes:
# Contribuciones de la computación moderna a un problema bastante complejo, pero con cautela
# Aunque hay muchos factores, cada vez los temas ecologicos van a tener un mayor peso sobre los conflictos. Aunque no lo explican del todo.
#
# - machine learning:
# implementación es bastante facil y hay mucho contenido en linea/documentación y paquetería para hacer uso de metodos seemingly complex. Lo desafiante es que no hay una sola solución correcta a un problema particular y por ende es bastante experimental: hay que probar con varios modelos, tinker para entender como puede mejorar la ejecución con las restricciones de cada sistema, y tener un registro de como performa cada modelo para encontrar un rumbo.
# Otra cosa interesante fue que los modelos no lineares parecen ser mas confaibles para aprender este fenomeno. Pero el policymaker tradicional esta muy aferrado a la regresión.
# Abre la puerta a la experimentación con datos un poco anómalos, diferentes fuentes, sensores distintos, altas dimensiones
#
# - further investigations:
#     - implementación en gobiernos
#     - Identify how it can be sensitive to be used by authoritarian governments, policing -> ethical
#     - Causas históricas, información colonial, otras continentes como Latam -> otro tipo de conflictos
#     - ecologia vs sociologia
#     - deep dive en los paises hotspots
#     - How to handle missing values? there's a lot of holes in our data
#     - What would happen if we dropped acccumulated conflict? what happens if we segregate between short term and long term
#     - Focus on units that have people living in them??
#
# - continuations on infinite resources and more time:
#     - red neuronal adversarial
#     - mas a profundidad con los ensemble methods
#     - remote sensing methods -> computación pesada -> mas granularidad -> costo de acceso y procesamiento
#     - stable production-level interface that is enhanced with new data revisions,
