# %% [markdown]
# # Conclusion: What did you learn about your research question? What did you learn about machine learning through the tasks?  How would you continue this research if you wanted to further investigate? If you had more time and infinite resources, how would you continue your project?
