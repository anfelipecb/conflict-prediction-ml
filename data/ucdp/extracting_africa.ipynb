# %% [markdown]
# #### Setting up

# %%
import pandas as pd

# %%
# needs to have the original file downloaded. 
raw_data = pd.read_csv("../../GEDEvent_v24_1.csv", low_memory=False)

# %%
# filtering for africa
africa_data = raw_data[raw_data["region"] == "Africa"]
africa_data
# Out:
#            id               relid  year  active_year code_status  \
# 42029    2629      ALG-1990-1-2-1  1990            0       Clear
# 42030    5751      ALG-1991-1-2-4  1991            1       Clear
# 42031    2587      ALG-1991-1-2-1  1991            1       Clear
# 42032    4216      ALG-1991-1-2-2  1991            1       Clear
# 42033    3160      ALG-1991-1-2-3  1991            1       Clear
# ...       ...                 ...   ...          ...         ...
# 349728  15525   MZM-1989-3-1347-4  1989            1       Clear
# 349729  15524  MZM-1989-3-1347-16  1989            1       Clear
# 349730  15245  MZM-1990-3-1347-18  1990            1       Clear
# 349731  15516  MZM-1990-3-1347-28  1990            1       Clear
# 349732  15493  MZM-1990-3-1347-29  1990            1       Clear
#
#         type_of_violence  conflict_dset_id  conflict_new_id  \
# 42029                  1               386              386
# 42030                  1               386              386
# ...
