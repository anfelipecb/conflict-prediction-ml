# %%
import pandas as pd
import geopandas as gpd

# %%
conflict_grid = gpd.read_file('/Users/anfelipecb/Library/CloudStorage/Box-Box/MSCAPP/3rd Quarter/Machine Learning/Project/project-aeyzaguirre-phernandezpedraz-afcamachob/data/output/grid_conflict.geojson')

# %%
conflict_grid
# Out:
#         GEOID  year  conflict_count  \
# 0           1  2017               0
# 1           1  2021               0
# 2           1  1989               0
# 3           1  1990               0
# 4           1  1991               0
# ...       ...   ...             ...
# 456255  13036  1999               0
# 456256  13036  2000               0
# 456257  13036  2001               0
# 456258  13036  2022               0
# 456259  13036  2023               0
#
#                                                  geometry
# 0       POLYGON ((-17.17448 14.27993, -17.17448 14.730...
# 1       POLYGON ((-17.17448 14.27993, -17.17448 14.730...
# 2       POLYGON ((-17.17448 14.27993, -17.17448 14.730...
# 3       POLYGON ((-17.17448 14.27993, -17.17448 14.730...
# 4       POLYGON ((-17.17448 14.27993, -17.17448 14.730...
# ...                                                   ...
# 456255  POLYGON ((51.31069 11.57723, 51.31069 12.02768...
# 456256  POLYGON ((51.31069 11.57723, 51.31069 12.02768...
# 456257  POLYGON ((51.31069 11.57723, 51.31069 12.02768...
# 456258  POLYGON ((51.31069 11.57723, 51.31069 12.02768...
# 456259  POLYGON ((51.31069 11.57723, 51.31069 12.02768...
#
# [456260 rows x 4 columns]

# %%
conflict_grid.groupby('year').agg({'GEOID': 'nunique'}).rename(columns ={'GEOID': 'Num_GRIDS'})
# Out:
#       Num_GRIDS
# year
# 1989      13036
# 1990      13036
# 1991      13036
# 1992      13036
# 1993      13036
# 1994      13036
# 1995      13036
# 1996      13036
# 1997      13036
# 1998      13036
# 1999      13036
# 2000      13036
# 2001      13036
# 2002      13036
# 2003      13036
# 2004      13036
# 2005      13036
# 2006      13036
# 2007      13036
# 2008      13036
# 2009      13036
# 2010      13036
# 2011      13036
# 2012      13036
# 2013      13036
# 2014      13036
# 2015      13036
# 2016      13036
# 2017      13036
# 2018      13036
# 2019      13036
# 2020      13036
# 2021      13036
# 2022      13036
# 2023      13036

# %%
#Read the final parquet
file_path = '/Users/anfelipecb/Library/CloudStorage/Box-Box/MSCAPP/3rd Quarter/Machine Learning/Project/project-aeyzaguirre-phernandezpedraz-afcamachob/data/output/grid_conflict_climate_rwi.parquet'
final_gdf = pd.read_parquet(file_path)

# %%
final_gdf
# Out:
#         GEOID  year  conflict_count   temp_mean    temp_max  precip_total  \
# 0           1  2017               0         NaN         NaN           NaN
# 1           1  2021               0         NaN         NaN           NaN
# 2           1  2006               0         NaN         NaN           NaN
# 3           1  2008               0         NaN         NaN           NaN
# 4           1  2009               0         NaN         NaN           NaN
# ...       ...   ...             ...         ...         ...           ...
# 234643  13036  2018               0  299.012965  309.124168      0.078476
# 234644  13036  2019               0  299.477335  310.209900      0.240952
# 234645  13036  2020               0  299.293418  309.668446      0.295275
# 234646  13036  2022               0  299.093328  309.628448      0.158219
# 234647  13036  2023               0  299.447113  309.861099      0.172341
#
#              sp_mean  rwi_2021  forest_loss  lights_mean  lights_sum  \
# 0                NaN  0.752576          0.0          NaN         NaN
# 1                NaN  0.752576          0.0     0.307777    3.693320
# 2                NaN  0.752576          0.0          NaN         NaN
# 3                NaN  0.752576          0.0          NaN         NaN
# 4                NaN  0.752576          0.0          NaN         NaN
# ...              ...       ...          ...          ...         ...
# 234643  96637.816447       NaN          0.0          NaN         NaN
# 234644  96638.664223       NaN          0.0     0.153874    1.846484
# 234645  96305.418242       NaN          0.0     0.241038    2.892451
# 234646  96282.639483       NaN          0.0     0.284016    3.408193
# 234647  96353.797019       NaN          0.0     0.330492    3.965908
#
#         accumulated_conflicts  temp_deviation
# 0                           0             NaN
# 1                           0             NaN
# 2                           0             NaN
# 3                           0             NaN
# 4                           0             NaN
# ...                       ...             ...
# 234643                      1       -0.182444
# 234644                      1        0.281926
# 234645                      1        0.098009
# 234646                      1       -0.102082
# 234647                      1        0.251703
#
# [234648 rows x 13 columns]

# %%
final_gdf['conflict_count'].value_counts()
# Out:
# conflict_count
# 0      225112
# 1        4271
# 2        1703
# 3         867
# 4         590
#         ...
# 96          1
# 95          1
# 126         1
# 81          1
# 167         1
# Name: count, Length: 101, dtype: int64

# %%
final_gdf[final_gdf['year'] >=2019]['conflict_count'].describe()
# Out:
# count    65180.000000
# mean         0.305063
# std          2.920662
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        304.000000
# Name: conflict_count, dtype: float64

# %%
final_gdf['year'].value_counts()
# Out:
# year
# 2017    13036
# 2021    13036
# 2022    13036
# 2020    13036
# 2019    13036
# 2018    13036
# 2015    13036
# 2007    13036
# 2016    13036
# 2014    13036
# 2013    13036
# 2012    13036
# 2011    13036
# 2010    13036
# 2009    13036
# 2008    13036
# 2006    13036
# 2023    13036
# Name: count, dtype: int64

# %%
final_gdf[final_gdf['year'] >=2019]['conflict_count'].value_counts()
# Out:
# conflict_count
# 0     61348
# 1      1552
# 2       634
# 3       353
# 4       252
#       ...
# 42        1
# 49        1
# 66        1
# 55        1
# 67        1
# Name: count, Length: 77, dtype: int64
